# %%
import numpy as np
import requests
import json
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
dictionary = cv2.aruco.custom_dictionary(20,3, 2020)
param = cv2.aruco.DetectorParameters_create()

# %%
nx = 2
ny = 10 
for id in range(ny):
    fig = plt.figure(figsize = (16, 9))
    for idx in range(nx):
        ax = fig.add_subplot(1, nx, idx+1)
        img = cv2.aruco.drawMarker(dictionary, 2*id + idx, 512, borderBits=1)
        plt.imshow(img, cmap = mpl.cm.gray, interpolation = "nearest")
        ax.axis("off")
        ax.set_title(2*id + idx)
    #plt.savefig(f"aruco-markers/markers{id}.png", dpi = 300)
    plt.show()

nx = 5
ny = 4
fig = plt.figure(figsize = (16, 9))
for idx in range(nx*ny):
    ax = fig.add_subplot(ny, nx, idx+1)
    img = cv2.aruco.drawMarker(dictionary, idx, 512, borderBits=1)
    plt.imshow(img, cmap = mpl.cm.gray, interpolation = "nearest")
    ax.axis("off")
    ax.set_title(idx)
#plt.savefig(f"aruco-markers/markers.png", dpi = 300)
plt.show()

# %%
frameGray = cv2.imread("aruco-markers/markers.png", cv2.IMREAD_GRAYSCALE)
corners, ids, rejPts = cv2.aruco.detectMarkers(frameGray, dictionary, parameters = param)
plt.figure()
plt.imshow(frameGray, cmap = mpl.cm.gray)
markers = np.zeros((20,4))
ids = ids.reshape(-1)
visible = np.ones((len(ids), 1))
corners = np.array(corners).squeeze(1)
vectors = np.diff(np.delete(corners,[2,3], axis=1),axis=1)
centers = corners.mean(1)
referenceVec = centers[np.where(ids==1)[0][0]] - centers[np.where(ids==0)[0][0]]
angles = np.arctan2(np.cross(vectors,referenceVec), np.dot(vectors, referenceVec))
markers = np.concatenate((centers, angles, visible), axis=1)
print(markers)
# Out:
# [[3.9995e+03 2.1405e+03 0.0000e+00 1.0000e+00]
#  [3.2295e+03 2.1405e+03 0.0000e+00 1.0000e+00]
#  [2.4595e+03 2.1405e+03 0.0000e+00 1.0000e+00]
#  [1.6905e+03 2.1405e+03 0.0000e+00 1.0000e+00]
#  [9.2050e+02 2.1405e+03 0.0000e+00 1.0000e+00]
#  [3.9995e+03 1.6090e+03 0.0000e+00 1.0000e+00]
#  [3.2295e+03 1.6090e+03 0.0000e+00 1.0000e+00]
#  [2.4595e+03 1.6090e+03 0.0000e+00 1.0000e+00]
#  [1.6905e+03 1.6090e+03 0.0000e+00 1.0000e+00]
#  [9.2050e+02 1.6090e+03 0.0000e+00 1.0000e+00]
#  [3.9995e+03 1.0770e+03 0.0000e+00 1.0000e+00]
#  [3.2295e+03 1.0770e+03 0.0000e+00 1.0000e+00]
#  [2.4595e+03 1.0770e+03 0.0000e+00 1.0000e+00]
#  [1.6905e+03 1.0770e+03 0.0000e+00 1.0000e+00]
#  [9.2050e+02 1.0770e+03 0.0000e+00 1.0000e+00]
#  [3.9995e+03 5.4500e+02 0.0000e+00 1.0000e+00]
#  [3.2295e+03 5.4500e+02 0.0000e+00 1.0000e+00]
#  [2.4595e+03 5.4500e+02 0.0000e+00 1.0000e+00]
#  [1.6905e+03 5.4500e+02 0.0000e+00 1.0000e+00]
#  [9.2050e+02 5.4500e+02 0.0000e+00 1.0000e+00]]
